# %% [markdown]
# # **MÓDULO 19**
# # Exercício: Estatística Aplicada

# %% [markdown]
# **Efetividade de Duas Estratégias de Ensino**
#
# Imagine que uma escola esteja avaliando a eficácia de duas estratégias de ensino de matemática para alunos do ensino médio. Eles querem determinar se há uma diferença significativa no desempenho médio dos alunos entre as duas estratégias.

# %% [markdown]
# # **Hipóteses:**
#
# * Hipótese nula (H0): A média das notas dos alunos na estratégia A é igual à média das notas dos alunos na estratégia B.
# * Hipótese alternativa (H1): A média das notas na Estratégia B é maior do que a média das notas na Estratégia A.

# %% [markdown]
# # **Dados:**
#
# * Amostra da Estratégia A: Notas de 50 alunos que receberam a Estratégia A.
# * Amostra da Estratégia B: Notas de 50 alunos que receberam a Estratégia B.

# %% [markdown]
# Usaremos um teste Z para comparar as médias das notas entre as duas amostras.

# %% [markdown]
# Se o p-valor do teste Z for menor que um nível de significância pré-determinado (por exemplo, α = 0.05), rejeitamos a hipótese nula e concluímos que há uma diferença significativa nas médias das notas entre as duas estratégias de ensino.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# Os dados são criados a seguir:

# %%
# Definindo médias e desvios padrão para as notas nas duas estratégias
media_estrategia_A = 70
desvio_padrao_estrategia_A = 10

media_estrategia_B = 75
desvio_padrao_estrategia_B = 12

# Gerando as amostras de notas para cada estratégia de ensino da nossa base
np.random.seed(0)  # Para garantir a reprodutibilidade dos resultados
amostra_estrategia_A = np.random.normal(loc=media_estrategia_A, scale=desvio_padrao_estrategia_A, size=50)
amostra_estrategia_B = np.random.normal(loc=media_estrategia_B, scale=desvio_padrao_estrategia_B, size=50)

print("Notas da Estratégia A:", amostra_estrategia_A[:5])
print("Notas da Estratégia B:", amostra_estrategia_B[:5])
# Out:
# Notas da Estratégia A: [87.64052346 74.00157208 79.78737984 92.40893199 88.6755799 ]
# Notas da Estratégia B: [64.25440127 79.64282997 68.87033835 60.83241379 74.66181326]

# %% [markdown]
# # 1) De acordo com as informações analisadas o nosso teste é unilateral á direita, esquerda ou bicaudal? Justifique.

# %% [markdown]
# ## Natureza do Teste Estatístico
#
# Nosso teste é **unilateral à direita**, pois estamos interessados em avaliar se a média das notas dos alunos que utilizaram a Estratégia B é **maior** do que a média das notas dos alunos que utilizaram a Estratégia A.
#
# ### Justificativa
#
# A formulação das hipóteses indica essa direção:
#
# - **Hipótese nula (H₀)**: A média das notas na Estratégia A é igual à média das notas na Estratégia B.
# - **Hipótese alternativa (H₁)**: A média das notas na Estratégia B é maior do que a média das notas na Estratégia A.
#
# Como estamos verificando se uma média é **superior** à outra, o teste é realizado apenas na **cauda direita** da distribuição Z.

# %% [markdown]
# # 2) Calcule as médias para as duas amostragens e as variâncias. Quais insights você pode retirar comparando os dados?

# %% [markdown]
# ### Resultados
#
# - **Média da Estratégia A:** \( 72.94 \)
# - **Média da Estratégia B:** \( 74.11 \)
# - **Variância da Estratégia A:** \( 47.68 \)
# - **Variância da Estratégia B:** \( 27.51 \)
#
# ### Insights
#
# 1. A **Estratégia B** apresentou uma média ligeiramente maior do que a Estratégia A, indicando que, em média, os alunos que seguiram a Estratégia B tiveram um desempenho um pouco melhor.
# 2. A **variância da Estratégia A** é significativamente maior do que a da Estratégia B, o que sugere que as notas dos alunos na Estratégia A são mais dispersas. Isso pode indicar que a Estratégia A tem resultados mais inconsistentes entre os alunos, enquanto a Estratégia B parece oferecer resultados mais estáveis.

# %% [markdown]
# # 3) Imprima os resultados da estatística do teste Z, p value e indique se rejeitaremos ou não a hipótese nula. Justifique sua resposta.

# %% [markdown]
# ### Resultados do Teste Z
#
# - **Estatística Z:** \( 0.95 \)
# - **P-valor:** \( 0.17 \)
# - **Nível de significância (\( \alpha \))**: \( 0.05 \)
# - **Rejeitamos \( H_0 \)?** Não.
#
# ### Justificativa
#
# O p-valor calculado (\( 0.17 \)) é maior do que o nível de significância adotado (\( \alpha = 0.05 \)). Isso significa que **não temos evidências estatísticas suficientes para rejeitar a hipótese nula** (\( H_0 \)).
#
# Portanto, não podemos concluir que a Estratégia B é significativamente melhor do que a Estratégia A em termos de desempenho médio dos alunos.

# %% [markdown]
# # 4) Para finalizar monte o gráfico da distribuição da estatística do nosso teste Z e explique o que pode ser observado através dele.

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

# Dados do teste Z
z_stat = 0.952302351506035  # Estatística Z calculada
nivel_significancia = 0.05  # Nível de significância

# Gerando valores para a curva da distribuição normal padrão
z_values = np.linspace(-3, 3, 1000)
z_distribution = norm.pdf(z_values)

# Plotando o gráfico
plt.figure(figsize=(10, 6))
plt.plot(z_values, z_distribution, label="Distribuição Normal Padrão", color="blue")
plt.axvline(z_stat, color="red", linestyle="--", label=f"Estatística Z = {z_stat:.2f}")
plt.fill_between(z_values, 0, z_distribution, where=(z_values >= z_stat), color="red", alpha=0.3, label="Região p-valor")
plt.axvline(norm.ppf(1 - nivel_significancia), color="green", linestyle="--", label="Valor crítico (Z crítico)")

# Personalização do gráfico
plt.title("Distribuição da Estatística do Teste Z", fontsize=14)
plt.xlabel("Z", fontsize=12)
plt.ylabel("Densidade de Probabilidade", fontsize=12)
plt.legend(fontsize=10)
plt.grid(alpha=0.3)
plt.show()

# %% [markdown]
# ### Observações do Gráfico
#
# 1. **Distribuição Normal Padrão**: A curva azul representa a distribuição normal padrão, que é utilizada para calcular o teste Z.
# 2. **Estatística Z (linha vermelha)**: A linha tracejada vermelha indica o valor da estatística Z calculado (\( Z = 0.95 \)).
# 3. **Região de p-valor**: A área sombreada em vermelho à direita da estatística Z representa o p-valor (\( 0.17 \)). Essa área indica a probabilidade de obtermos um valor Z igual ou maior que o observado, sob a hipótese nula.
# 4. **Valor crítico (linha verde)**: A linha tracejada verde indica o valor crítico de \( Z \) para o nível de significância de 5% (\( Z_{crítico} \approx 1.645 \)). Para rejeitar \( H_0 \), o valor Z observado deveria estar à direita dessa linha.
#
# ### Conclusão
#
# Como a estatística Z observada (\( 0.95 \)) está à esquerda do valor crítico (\( 1.645 \)) e a área sombreada (p-valor) é maior que o nível de significância (\( \alpha = 0.05 \)), não há evidências suficientes para rejeitar a hipótese nula. Isso reforça que não podemos concluir que a Estratégia B é significativamente melhor do que a Estratégia A.
